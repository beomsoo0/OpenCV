# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-bda22c77-7b5e-48ae-8300-7ce8f3a0a5ca" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bda22c77-7b5e-48ae-8300-7ce8f3a0a5ca">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving beom.jpg to beom.jpg

# %%
import cv2
import matplotlib.pyplot as plt

image = cv2.imread('beom.jpg')
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

expand = cv2.resize(image, None, fx = 2.0, fy = 2.0, interpolation = cv2.INTER_CUBIC)
plt.imshow(cv2.cvtColor(expand, cv2.COLOR_BGR2RGB))
plt.show()

shrink = cv2.resize(image, None, fx = 0.8, fy = 0.8, interpolation = cv2.INTER_AREA)
plt.imshow(cv2.cvtColor(shrink, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# cv2.resize(image, dsize, fx, fy, interpolation)
# 이미지 크기 변환

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

image = cv2.imread('beom.jpg')

# 행과 열 정보만 가져오기
height, width = image.shape[:2]

M = np.float32([[1, 0, 500], [0, 1, 100]])
dst = cv2.warpAffine(image, M, (width, height))

plt.imshow(cv2.cvtColor(dst, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# cv2.warpAffine(image, M, size)
# 이미지 위치 변경

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

image = cv2.imread('beom.jpg')

height, width = image.shape[:2]

M = cv2.getRotationMatrix2D((width/2, height/2), 90, 0.5)
dst = cv2.warpAffine(image, M, (width, height))

plt.imshow(cv2.cvtColor(dst, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# 이미지 회전
# cv2.getRotationMatrix(center,angle, scale)
