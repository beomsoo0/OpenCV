# %%
import cv2

from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6b2c0fea-154e-425b-a156-03c4d7b2eb48" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6b2c0fea-154e-425b-a156-03c4d7b2eb48">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving sim.jpg to sim (1).jpg
# Saving soo.jpg to soo.jpg

# %%
import cv2
import matplotlib.pyplot as plt

soo = cv2.imread('soo.jpg')
sim = cv2.imread('sim.jpg')

roi = soo[350:550, 380:550]
sim[900:1100, 400:570] = roi
plt.imshow(cv2.cvtColor(sim, cv2.COLOR_BGR2RGB))
plt.show()
