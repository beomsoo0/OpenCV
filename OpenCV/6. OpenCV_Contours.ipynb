# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-98a9baf6-ad18-497b-b228-14f9f57c0192" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-98a9baf6-ad18-497b-b228-14f9f57c0192">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving gray_image.jpg to gray_image.jpg

# %%
import cv2
import matplotlib.pyplot as plt

image = cv2.imread('gray_image.jpg')
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)     # BGR -> GRAY
ret, thresh = cv2.threshold(image_gray, 127, 255, 0)     # 127 기준으로 GRAY 이미지 Thresholding

plt.imshow(cv2.cvtColor(thresh, cv2.COLOR_GRAY2RGB))
plt.show()

contours = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)[0]
image = cv2.drawContours(image, contours, -1, (0, 255, 0), 4)

plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# cv2.findContours(image, mode, method): 이미지에서 Contour들을 찾는 함수
#
# *   mode
#
# 1) RETR_EXTERNAL: 바깥쪽 Line만 찾기
#
# 2) RETR_LIST: 모든 Line을 찾지만, Hierarchy 구성 X
#
# 3) RETR_TREE: 모든 Line을 찾으며, 모든 Hierarchy 구성 O
#
# *   method
#
# 1) CHAIN_APPROX_NONE: 모든 Contour 포인트 저장
#
# 2) CHAIN_APPROX_SIMPLE: Contour Line을 그릴 수 있는 포인트만 저장
